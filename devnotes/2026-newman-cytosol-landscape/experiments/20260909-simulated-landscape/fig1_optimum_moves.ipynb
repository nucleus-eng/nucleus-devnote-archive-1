# %% [markdown]
# # Figure 1 — adding a module can move the optimum
#
# Steady-state yield against magnesium, before and after adding Protein X. At the
# magnesium you originally picked, the new system looks worse. Move along the
# magnesium axis and most of the yield is still there — the optimum moved, it did
# not disappear.
#
# The curves are illustrative Gaussians, **not fitted data**. Ranges and
# amplitudes are set to sit inside what our own sweeps actually cover (Mg
# 0–24 mM, yields up to ~50 ng/µL) so the picture doesn't imply a regime we've
# never run.
#
# The plotting code lives in `fig1_optimum_moves.py` beside this notebook, which
# also carries the `--banner` and `--surface-only` modes that generate this
# DevNote's banner and thumbnail.

# %%
# %matplotlib inline
from fig1_optimum_moves import make_figure

# %% [markdown]
# Both panels are cuts through the same surface: the left-hand curves are the
# `Protein X = 0` and `Protein X = 0.6 a.u.` slices of the contour plot on the
# right, so the two panels cannot disagree.

# %%
#| label: fig:optimum-moves

fig = make_figure(two_panel=True)
